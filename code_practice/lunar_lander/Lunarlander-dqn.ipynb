# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque, namedtuple
import random
import matplotlib.pyplot as plt

# %%
# 1. 环境初始化[1,4](@ref)
env = gym.make("LunarLander-v3", render_mode="rgb_array")
state_dim = env.observation_space.shape[0]  # 状态维度：8 (位置/速度/角度等)
action_dim = env.action_space.n             # 动作维度：4 (无操作/主引擎/左/右)

# %%
# 2. DQN神经网络[8](@ref)
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim)
        )
    
    def forward(self, x):
        return self.net(x)

# %%
# 3. 经验回放缓存[8](@ref)
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))
class ReplayBuffer:
    def __init__(self, capacity=10000):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, *args):
        self.buffer.append(Transition(*args))
    
    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)
    
    def __len__(self):
        return len(self.buffer)

# %%
# 4. DQN智能体
class DQNAgent:
    def __init__(self, state_dim, action_dim):
        self.policy_net = DQN(state_dim, action_dim)   # 策略网络
        self.target_net = DQN(state_dim, action_dim)   # 目标网络（稳定训练）
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=1e-3)
        self.buffer = ReplayBuffer()
        self.batch_size = 64
        self.gamma = 0.99      # 折扣因子[8](@ref)
        self.epsilon = 1.0     # 探索率
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        
    def act(self, state):
        if np.random.rand() < self.epsilon:  # epsilon-贪婪策略[2](@ref)
            return env.action_space.sample()
        else:
            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state).argmax().item()
    
    def update(self):
        if len(self.buffer) < self.batch_size:
            return
            
        # 从缓存中采样
        transitions = self.buffer.sample(self.batch_size)
        batch = Transition(*zip(*transitions))
        
        # 转换数据为张量
        state_batch = torch.tensor(np.array(batch.state), dtype=torch.float32)
        action_batch = torch.tensor(batch.action, dtype=torch.long).unsqueeze(1)
        reward_batch = torch.tensor(batch.reward, dtype=torch.float32)
        next_state_batch = torch.tensor(np.array(batch.next_state), dtype=torch.float32)
        done_batch = torch.tensor(batch.done, dtype=torch.float32)
        
        # 计算Q值
        q_values = self.policy_net(state_batch).gather(1, action_batch)
        next_q_values = self.target_net(next_state_batch).max(1)[0].detach()
        expected_q = reward_batch + self.gamma * next_q_values * (1 - done_batch)
        
        # 计算损失
        loss = nn.MSELoss()(q_values, expected_q.unsqueeze(1))
        
        # 优化模型
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        # 更新目标网络（软更新）
        target_net_state = self.target_net.state_dict()
        policy_net_state = self.policy_net.state_dict()
        for key in policy_net_state:
            target_net_state[key] = 0.01 * policy_net_state[key] + 0.99 * target_net_state[key]
        self.target_net.load_state_dict(target_net_state)
        
        # 衰减探索率
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
# 5. 训练逻辑
agent = DQNAgent(state_dim, action_dim)
episode_rewards = []

for episode in range(500):  # 训练500轮
    state, _ = env.reset()
    total_reward = 0
    done = False
    
    while not done:
        action = agent.act(state)  # 选择动作
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # 存储经验[8](@ref)
        agent.buffer.push(state, action, reward, next_state, done)
        agent.update()  # 更新网络
        
        state = next_state
        total_reward += reward
    
    episode_rewards.append(total_reward)
    print(f"Episode {episode}: Reward={total_reward:.2f}, Epsilon={agent.epsilon:.3f}")
# Out:
# Episode 0: Reward=-71.07, Epsilon=0.956
# Episode 1: Reward=-335.25, Epsilon=0.513
# Episode 2: Reward=-119.95, Epsilon=0.197
# Episode 3: Reward=-141.97, Epsilon=0.082
# Episode 4: Reward=-626.91, Epsilon=0.048
# Episode 5: Reward=56.04, Epsilon=0.019
# Episode 6: Reward=-87.70, Epsilon=0.010
# Episode 7: Reward=-74.30, Epsilon=0.010
# Episode 8: Reward=-21.74, Epsilon=0.010
# Episode 9: Reward=-92.11, Epsilon=0.010
# Episode 10: Reward=-93.02, Epsilon=0.010
# Episode 11: Reward=-73.71, Epsilon=0.010
# Episode 12: Reward=-91.02, Epsilon=0.010
# Episode 13: Reward=-131.80, Epsilon=0.010
# Episode 14: Reward=-42.16, Epsilon=0.010
# Episode 15: Reward=-97.04, Epsilon=0.010
# Episode 16: Reward=-120.57, Epsilon=0.010
# Episode 17: Reward=-72.66, Epsilon=0.010
# Episode 18: Reward=-132.55, Epsilon=0.010
# Episode 19: Reward=-98.85, Epsilon=0.010
# Episode 20: Reward=-114.56, Epsilon=0.010
# Episode 21: Reward=-28.37, Epsilon=0.010
# Episode 22: Reward=-117.75, Epsilon=0.010
# Episode 23: Reward=-73.68, Epsilon=0.010
# Episode 24: Reward=-117.98, Epsilon=0.010
# Episode 25: Reward=-157.54, Epsilon=0.010
# Episode 26: Reward=-69.11, Epsilon=0.010
# Episode 27: Reward=-25.17, Epsilon=0.010
# Episode 28: Reward=-39.48, Epsilon=0.010
# Episode 29: Reward=-75.26, Epsilon=0.010
# Episode 30: Reward=-51.89, Epsilon=0.010
# Episode 31: Reward=-3.45, Epsilon=0.010
# Episode 32: Reward=1.84, Epsilon=0.010
# Episode 33: Reward=-383.47, Epsilon=0.010
# Episode 34: Reward=-45.35, Epsilon=0.010
# Episode 35: Reward=-48.35, Epsilon=0.010
# Episode 36: Reward=-7.42, Epsilon=0.010
# Episode 37: Reward=-182.38, Epsilon=0.010
# Episode 38: Reward=-77.97, Epsilon=0.010
# Episode 39: Reward=-83.63, Epsilon=0.010
# Episode 40: Reward=-86.63, Epsilon=0.010
# Episode 41: Reward=-513.82, Epsilon=0.010
# Episode 42: Reward=-92.37, Epsilon=0.010
# Episode 43: Reward=-25.10, Epsilon=0.010
# Episode 44: Reward=10.71, Epsilon=0.010
# Episode 45: Reward=-89.17, Epsilon=0.010
# Episode 46: Reward=-10.76, Epsilon=0.010
# Episode 47: Reward=-24.39, Epsilon=0.010
# Episode 48: Reward=-69.12, Epsilon=0.010
# Episode 49: Reward=-43.58, Epsilon=0.010
# Episode 50: Reward=-51.91, Epsilon=0.010
# Episode 51: Reward=-110.38, Epsilon=0.010
# Episode 52: Reward=-45.05, Epsilon=0.010
# Episode 53: Reward=-56.71, Epsilon=0.010
# Episode 54: Reward=-49.39, Epsilon=0.010
# Episode 55: Reward=-68.61, Epsilon=0.010
# Episode 56: Reward=-110.50, Epsilon=0.010
# Episode 57: Reward=-31.30, Epsilon=0.010
# Episode 58: Reward=-69.01, Epsilon=0.010
# Episode 59: Reward=-75.97, Epsilon=0.010
# Episode 60: Reward=-63.93, Epsilon=0.010
# Episode 61: Reward=-31.89, Epsilon=0.010
# Episode 62: Reward=-1.76, Epsilon=0.010
# Episode 63: Reward=-147.09, Epsilon=0.010
# Episode 64: Reward=-35.75, Epsilon=0.010
# Episode 65: Reward=-87.61, Epsilon=0.010
# Episode 66: Reward=-35.70, Epsilon=0.010
# Episode 67: Reward=-139.95, Epsilon=0.010
# Episode 68: Reward=-311.66, Epsilon=0.010
# Episode 69: Reward=6.73, Epsilon=0.010
# Episode 70: Reward=-87.48, Epsilon=0.010
# Episode 71: Reward=-73.49, Epsilon=0.010
# Episode 72: Reward=-60.68, Epsilon=0.010
# Episode 73: Reward=-50.44, Epsilon=0.010
# Episode 74: Reward=-39.22, Epsilon=0.010
# Episode 75: Reward=-41.02, Epsilon=0.010
# Episode 76: Reward=-63.56, Epsilon=0.010
# Episode 77: Reward=-74.73, Epsilon=0.010
# Episode 78: Reward=-68.02, Epsilon=0.010
# Episode 79: Reward=-64.19, Epsilon=0.010
# Episode 80: Reward=-38.08, Epsilon=0.010
# Episode 81: Reward=-8.88, Epsilon=0.010
# Episode 82: Reward=-63.35, Epsilon=0.010
# Episode 83: Reward=-42.18, Epsilon=0.010
# Episode 84: Reward=-35.48, Epsilon=0.010
# Episode 85: Reward=-34.05, Epsilon=0.010
# Episode 86: Reward=-112.10, Epsilon=0.010
# Episode 87: Reward=-7.08, Epsilon=0.010
# Episode 88: Reward=-42.06, Epsilon=0.010
# Episode 89: Reward=-21.91, Epsilon=0.010
# Episode 90: Reward=-18.23, Epsilon=0.010
# Episode 91: Reward=-40.53, Epsilon=0.010
# Episode 92: Reward=-29.95, Epsilon=0.010
# Episode 93: Reward=-9.77, Epsilon=0.010
# Episode 94: Reward=-150.93, Epsilon=0.010
# Episode 95: Reward=16.03, Epsilon=0.010
# Episode 96: Reward=-81.29, Epsilon=0.010
# Episode 97: Reward=-262.86, Epsilon=0.010
# Episode 98: Reward=-35.80, Epsilon=0.010
# Episode 99: Reward=-53.49, Epsilon=0.010
# Episode 100: Reward=-32.41, Epsilon=0.010
# Episode 101: Reward=-48.44, Epsilon=0.010
# Episode 102: Reward=-19.87, Epsilon=0.010
# Episode 103: Reward=-96.06, Epsilon=0.010
# Episode 104: Reward=2.63, Epsilon=0.010
# Episode 105: Reward=-59.27, Epsilon=0.010
# Episode 106: Reward=-20.87, Epsilon=0.010
# Episode 107: Reward=-28.00, Epsilon=0.010
# Episode 108: Reward=-352.65, Epsilon=0.010
# Episode 109: Reward=-262.19, Epsilon=0.010
# Episode 110: Reward=-341.26, Epsilon=0.010
# Episode 111: Reward=-606.74, Epsilon=0.010
# Episode 112: Reward=-516.08, Epsilon=0.010
# Episode 113: Reward=-40.34, Epsilon=0.010
# Episode 114: Reward=-139.88, Epsilon=0.010
# Episode 115: Reward=-22.85, Epsilon=0.010
# Episode 116: Reward=-519.78, Epsilon=0.010
# Episode 117: Reward=-226.42, Epsilon=0.010
# Episode 118: Reward=-181.40, Epsilon=0.010
# Episode 119: Reward=-220.25, Epsilon=0.010
# Episode 120: Reward=-178.97, Epsilon=0.010
# Episode 121: Reward=240.97, Epsilon=0.010
# Episode 122: Reward=-47.41, Epsilon=0.010
# Episode 123: Reward=-392.24, Epsilon=0.010
# Episode 124: Reward=175.73, Epsilon=0.010
# Episode 125: Reward=191.80, Epsilon=0.010
# Episode 126: Reward=-132.18, Epsilon=0.010
# Episode 127: Reward=252.62, Epsilon=0.010
# Episode 128: Reward=215.53, Epsilon=0.010
# Episode 129: Reward=257.73, Epsilon=0.010
# Episode 130: Reward=198.44, Epsilon=0.010
# Episode 131: Reward=252.40, Epsilon=0.010
# Episode 132: Reward=250.94, Epsilon=0.010
# Episode 133: Reward=256.72, Epsilon=0.010
# Episode 134: Reward=237.10, Epsilon=0.010
# Episode 135: Reward=242.86, Epsilon=0.010
# Episode 136: Reward=306.56, Epsilon=0.010
# Episode 137: Reward=-571.85, Epsilon=0.010
# Episode 138: Reward=-461.68, Epsilon=0.010
# Episode 139: Reward=239.14, Epsilon=0.010
# Episode 140: Reward=278.96, Epsilon=0.010
# Episode 141: Reward=-280.74, Epsilon=0.010
# Episode 142: Reward=261.77, Epsilon=0.010
# Episode 143: Reward=256.05, Epsilon=0.010
# Episode 144: Reward=43.16, Epsilon=0.010
# Episode 145: Reward=58.88, Epsilon=0.010
# Episode 146: Reward=208.45, Epsilon=0.010
# Episode 147: Reward=-276.26, Epsilon=0.010
# Episode 148: Reward=258.31, Epsilon=0.010
# Episode 149: Reward=-243.45, Epsilon=0.010
# Episode 150: Reward=14.11, Epsilon=0.010
# Episode 151: Reward=42.38, Epsilon=0.010
# Episode 152: Reward=251.41, Epsilon=0.010
# Episode 153: Reward=31.26, Epsilon=0.010
# Episode 154: Reward=4.21, Epsilon=0.010
# Episode 155: Reward=-12.13, Epsilon=0.010
# Episode 156: Reward=14.74, Epsilon=0.010
# Episode 157: Reward=18.71, Epsilon=0.010
# Episode 158: Reward=-12.32, Epsilon=0.010
# Episode 159: Reward=218.79, Epsilon=0.010
# Episode 160: Reward=-70.90, Epsilon=0.010
# Episode 161: Reward=262.57, Epsilon=0.010
# Episode 162: Reward=256.67, Epsilon=0.010
# Episode 163: Reward=221.99, Epsilon=0.010
# Episode 164: Reward=258.07, Epsilon=0.010
# Episode 165: Reward=240.20, Epsilon=0.010
# Episode 166: Reward=-62.75, Epsilon=0.010
# Episode 167: Reward=266.51, Epsilon=0.010
# Episode 168: Reward=232.36, Epsilon=0.010
# Episode 169: Reward=38.91, Epsilon=0.010
# Episode 170: Reward=245.17, Epsilon=0.010
# Episode 171: Reward=250.74, Epsilon=0.010
# Episode 172: Reward=235.12, Epsilon=0.010
# Episode 173: Reward=243.79, Epsilon=0.010
# Episode 174: Reward=183.75, Epsilon=0.010
# Episode 175: Reward=253.32, Epsilon=0.010
# Episode 176: Reward=280.20, Epsilon=0.010
# Episode 177: Reward=0.89, Epsilon=0.010
# Episode 178: Reward=10.91, Epsilon=0.010
# Episode 179: Reward=271.14, Epsilon=0.010
# Episode 180: Reward=191.20, Epsilon=0.010
# Episode 181: Reward=-262.20, Epsilon=0.010
# Episode 182: Reward=247.47, Epsilon=0.010
# Episode 183: Reward=287.87, Epsilon=0.010
# Episode 184: Reward=247.29, Epsilon=0.010
# Episode 185: Reward=-137.31, Epsilon=0.010
# Episode 186: Reward=257.48, Epsilon=0.010
# Episode 187: Reward=301.35, Epsilon=0.010
# Episode 188: Reward=246.77, Epsilon=0.010
# Episode 189: Reward=247.97, Epsilon=0.010
# Episode 190: Reward=-14.44, Epsilon=0.010
# Episode 191: Reward=231.54, Epsilon=0.010
# Episode 192: Reward=256.33, Epsilon=0.010
# Episode 193: Reward=244.53, Epsilon=0.010
# Episode 194: Reward=231.50, Epsilon=0.010
# Episode 195: Reward=275.18, Epsilon=0.010
# Episode 196: Reward=280.02, Epsilon=0.010
# Episode 197: Reward=5.67, Epsilon=0.010
# Episode 198: Reward=222.95, Epsilon=0.010
# Episode 199: Reward=282.35, Epsilon=0.010
# Episode 200: Reward=261.62, Epsilon=0.010
# Episode 201: Reward=71.81, Epsilon=0.010
# Episode 202: Reward=-125.12, Epsilon=0.010
# Episode 203: Reward=-447.67, Epsilon=0.010
# Episode 204: Reward=239.53, Epsilon=0.010
# Episode 205: Reward=268.31, Epsilon=0.010
# Episode 206: Reward=230.68, Epsilon=0.010
# Episode 207: Reward=250.26, Epsilon=0.010
# Episode 208: Reward=269.11, Epsilon=0.010
# Episode 209: Reward=-505.59, Epsilon=0.010
# Episode 210: Reward=279.35, Epsilon=0.010
# Episode 211: Reward=-156.33, Epsilon=0.010
# Episode 212: Reward=186.46, Epsilon=0.010
# Episode 213: Reward=252.04, Epsilon=0.010
# Episode 214: Reward=235.07, Epsilon=0.010
# Episode 215: Reward=267.67, Epsilon=0.010
# Episode 216: Reward=-78.38, Epsilon=0.010
# Episode 217: Reward=-1.01, Epsilon=0.010
# Episode 218: Reward=258.87, Epsilon=0.010
# Episode 219: Reward=7.95, Epsilon=0.010
# Episode 220: Reward=241.01, Epsilon=0.010
# Episode 221: Reward=216.76, Epsilon=0.010
# Episode 222: Reward=213.10, Epsilon=0.010
# Episode 223: Reward=235.10, Epsilon=0.010
# Episode 224: Reward=239.11, Epsilon=0.010
# Episode 225: Reward=238.18, Epsilon=0.010
# Episode 226: Reward=248.86, Epsilon=0.010
# Episode 227: Reward=133.53, Epsilon=0.010
# Episode 228: Reward=246.18, Epsilon=0.010
# Episode 229: Reward=251.67, Epsilon=0.010
# Episode 230: Reward=262.08, Epsilon=0.010
# Episode 231: Reward=258.23, Epsilon=0.010
# Episode 232: Reward=277.57, Epsilon=0.010
# Episode 233: Reward=279.62, Epsilon=0.010
# Episode 234: Reward=250.71, Epsilon=0.010
# Episode 235: Reward=234.57, Epsilon=0.010
# Episode 236: Reward=256.55, Epsilon=0.010
# Episode 237: Reward=249.97, Epsilon=0.010
# Episode 238: Reward=-447.14, Epsilon=0.010
# Episode 239: Reward=217.83, Epsilon=0.010
# Episode 240: Reward=292.81, Epsilon=0.010
# Episode 241: Reward=266.76, Epsilon=0.010
# Episode 242: Reward=205.51, Epsilon=0.010
# Episode 243: Reward=-25.49, Epsilon=0.010
# Episode 244: Reward=-108.04, Epsilon=0.010
# Episode 245: Reward=257.67, Epsilon=0.010
# Episode 246: Reward=237.23, Epsilon=0.010
# Episode 247: Reward=234.09, Epsilon=0.010
# Episode 248: Reward=237.33, Epsilon=0.010
# Episode 249: Reward=256.76, Epsilon=0.010
# Episode 250: Reward=173.44, Epsilon=0.010
# Episode 251: Reward=290.34, Epsilon=0.010
# Episode 252: Reward=240.29, Epsilon=0.010
# Episode 253: Reward=233.78, Epsilon=0.010
# Episode 254: Reward=250.40, Epsilon=0.010
# Episode 255: Reward=112.56, Epsilon=0.010
# Episode 256: Reward=265.94, Epsilon=0.010
# Episode 257: Reward=274.41, Epsilon=0.010
# Episode 258: Reward=289.67, Epsilon=0.010
# Episode 259: Reward=274.40, Epsilon=0.010
# Episode 260: Reward=286.80, Epsilon=0.010
# Episode 261: Reward=284.48, Epsilon=0.010
# Episode 262: Reward=273.52, Epsilon=0.010
# Episode 263: Reward=283.62, Epsilon=0.010
# Episode 264: Reward=281.03, Epsilon=0.010
# Episode 265: Reward=293.86, Epsilon=0.010
# Episode 266: Reward=299.30, Epsilon=0.010
# Episode 267: Reward=264.37, Epsilon=0.010
# Episode 268: Reward=268.60, Epsilon=0.010
# Episode 269: Reward=270.26, Epsilon=0.010
# Episode 270: Reward=239.63, Epsilon=0.010
# Episode 271: Reward=233.73, Epsilon=0.010
# Episode 272: Reward=268.64, Epsilon=0.010
# Episode 273: Reward=289.84, Epsilon=0.010
# Episode 274: Reward=285.20, Epsilon=0.010
# Episode 275: Reward=306.56, Epsilon=0.010
# Episode 276: Reward=297.74, Epsilon=0.010
# Episode 277: Reward=247.79, Epsilon=0.010
# Episode 278: Reward=261.53, Epsilon=0.010
# Episode 279: Reward=52.20, Epsilon=0.010
# Episode 280: Reward=218.71, Epsilon=0.010
# Episode 281: Reward=-12.10, Epsilon=0.010
# Episode 282: Reward=274.39, Epsilon=0.010
# Episode 283: Reward=-109.43, Epsilon=0.010
# Episode 284: Reward=272.05, Epsilon=0.010
# Episode 285: Reward=284.42, Epsilon=0.010
# Episode 286: Reward=257.24, Epsilon=0.010
# Episode 287: Reward=9.97, Epsilon=0.010
# Episode 288: Reward=53.96, Epsilon=0.010
# Episode 289: Reward=248.00, Epsilon=0.010
# Episode 290: Reward=32.40, Epsilon=0.010
# Episode 291: Reward=166.45, Epsilon=0.010
# Episode 292: Reward=161.98, Epsilon=0.010
# Episode 293: Reward=8.38, Epsilon=0.010
# Episode 294: Reward=240.98, Epsilon=0.010
# Episode 295: Reward=159.72, Epsilon=0.010
# Episode 296: Reward=235.30, Epsilon=0.010
# Episode 297: Reward=263.53, Epsilon=0.010
# Episode 298: Reward=200.11, Epsilon=0.010
# Episode 299: Reward=222.94, Epsilon=0.010
# Episode 300: Reward=270.84, Epsilon=0.010
# Episode 301: Reward=259.51, Epsilon=0.010
# Episode 302: Reward=252.12, Epsilon=0.010
# Episode 303: Reward=269.35, Epsilon=0.010
# Episode 304: Reward=271.31, Epsilon=0.010
# Episode 305: Reward=259.50, Epsilon=0.010
# Episode 306: Reward=254.21, Epsilon=0.010
# Episode 307: Reward=233.71, Epsilon=0.010
# Episode 308: Reward=261.94, Epsilon=0.010
# Episode 309: Reward=223.00, Epsilon=0.010
# Episode 310: Reward=274.76, Epsilon=0.010
# Episode 311: Reward=279.54, Epsilon=0.010
# Episode 312: Reward=223.54, Epsilon=0.010
# Episode 313: Reward=-431.00, Epsilon=0.010
# Episode 314: Reward=308.17, Epsilon=0.010
# Episode 315: Reward=268.94, Epsilon=0.010
# Episode 316: Reward=253.00, Epsilon=0.010
# Episode 317: Reward=249.73, Epsilon=0.010
# Episode 318: Reward=279.19, Epsilon=0.010
# Episode 319: Reward=270.98, Epsilon=0.010
# Episode 320: Reward=259.92, Epsilon=0.010
# Episode 321: Reward=269.23, Epsilon=0.010
# Episode 322: Reward=-22.20, Epsilon=0.010
# Episode 323: Reward=274.37, Epsilon=0.010
# Episode 324: Reward=270.37, Epsilon=0.010
# Episode 325: Reward=295.15, Epsilon=0.010
# Episode 326: Reward=304.20, Epsilon=0.010
# Episode 327: Reward=34.08, Epsilon=0.010
# Episode 328: Reward=292.77, Epsilon=0.010
# Episode 329: Reward=252.71, Epsilon=0.010
# Episode 330: Reward=265.27, Epsilon=0.010
# Episode 331: Reward=245.62, Epsilon=0.010
# Episode 332: Reward=-437.09, Epsilon=0.010
# Episode 333: Reward=-375.48, Epsilon=0.010
# Episode 334: Reward=224.97, Epsilon=0.010
# Episode 335: Reward=237.23, Epsilon=0.010
# Episode 336: Reward=232.39, Epsilon=0.010
# Episode 337: Reward=262.62, Epsilon=0.010
# Episode 338: Reward=247.10, Epsilon=0.010
# Episode 339: Reward=279.50, Epsilon=0.010
# Episode 340: Reward=267.51, Epsilon=0.010
# Episode 341: Reward=311.96, Epsilon=0.010
# Episode 342: Reward=292.48, Epsilon=0.010
# Episode 343: Reward=-106.86, Epsilon=0.010
# Episode 344: Reward=262.45, Epsilon=0.010
# Episode 345: Reward=256.05, Epsilon=0.010
# Episode 346: Reward=230.72, Epsilon=0.010
# Episode 347: Reward=228.29, Epsilon=0.010
# Episode 348: Reward=247.73, Epsilon=0.010
# Episode 349: Reward=258.54, Epsilon=0.010
# Episode 350: Reward=282.23, Epsilon=0.010
# Episode 351: Reward=242.60, Epsilon=0.010
# Episode 352: Reward=189.27, Epsilon=0.010
# Episode 353: Reward=272.77, Epsilon=0.010
# Episode 354: Reward=258.34, Epsilon=0.010
# Episode 355: Reward=274.31, Epsilon=0.010
# Episode 356: Reward=285.29, Epsilon=0.010
# Episode 357: Reward=299.53, Epsilon=0.010
# Episode 358: Reward=-33.83, Epsilon=0.010
# Episode 359: Reward=-37.58, Epsilon=0.010
# Episode 360: Reward=-40.88, Epsilon=0.010
# Episode 361: Reward=246.34, Epsilon=0.010
# Episode 362: Reward=300.30, Epsilon=0.010
# Episode 363: Reward=6.83, Epsilon=0.010
# Episode 364: Reward=-76.76, Epsilon=0.010
# Episode 365: Reward=273.08, Epsilon=0.010
# Episode 366: Reward=234.41, Epsilon=0.010
# Episode 367: Reward=-35.06, Epsilon=0.010
# Episode 368: Reward=258.44, Epsilon=0.010
# Episode 369: Reward=268.91, Epsilon=0.010
# Episode 370: Reward=259.96, Epsilon=0.010
# Episode 371: Reward=270.21, Epsilon=0.010
# Episode 372: Reward=225.88, Epsilon=0.010
# Episode 373: Reward=-340.19, Epsilon=0.010
# Episode 374: Reward=243.55, Epsilon=0.010
# Episode 375: Reward=289.81, Epsilon=0.010
# Episode 376: Reward=246.42, Epsilon=0.010
# Episode 377: Reward=-100.18, Epsilon=0.010
# Episode 378: Reward=262.87, Epsilon=0.010
# Episode 379: Reward=275.50, Epsilon=0.010
# Episode 380: Reward=-119.79, Epsilon=0.010
# Episode 381: Reward=-205.69, Epsilon=0.010
# Episode 382: Reward=-13.85, Epsilon=0.010
# Episode 383: Reward=283.02, Epsilon=0.010
# Episode 384: Reward=258.86, Epsilon=0.010
# Episode 385: Reward=266.41, Epsilon=0.010
# Episode 386: Reward=-108.59, Epsilon=0.010
# Episode 387: Reward=-102.08, Epsilon=0.010
# Episode 388: Reward=-111.50, Epsilon=0.010
# Episode 389: Reward=-99.17, Epsilon=0.010
# Episode 390: Reward=281.27, Epsilon=0.010
# Episode 391: Reward=2.07, Epsilon=0.010
# Episode 392: Reward=239.81, Epsilon=0.010
# Episode 393: Reward=-31.22, Epsilon=0.010
# Episode 394: Reward=247.62, Epsilon=0.010
# Episode 395: Reward=258.72, Epsilon=0.010
# Episode 396: Reward=240.00, Epsilon=0.010
# Episode 397: Reward=-139.89, Epsilon=0.010
# Episode 398: Reward=246.79, Epsilon=0.010
# Episode 399: Reward=275.91, Epsilon=0.010
# Episode 400: Reward=248.30, Epsilon=0.010
# Episode 401: Reward=119.80, Epsilon=0.010
# Episode 402: Reward=265.29, Epsilon=0.010
# Episode 403: Reward=-101.97, Epsilon=0.010
# Episode 404: Reward=257.87, Epsilon=0.010
# Episode 405: Reward=-53.28, Epsilon=0.010
# Episode 406: Reward=250.87, Epsilon=0.010
# Episode 407: Reward=-95.73, Epsilon=0.010
# Episode 408: Reward=237.57, Epsilon=0.010
# Episode 409: Reward=231.49, Epsilon=0.010
# Episode 410: Reward=212.55, Epsilon=0.010
# Episode 411: Reward=240.46, Epsilon=0.010
# Episode 412: Reward=269.15, Epsilon=0.010
# Episode 413: Reward=254.86, Epsilon=0.010
# Episode 414: Reward=-61.80, Epsilon=0.010
# Episode 415: Reward=264.40, Epsilon=0.010
# Episode 416: Reward=286.15, Epsilon=0.010
# Episode 417: Reward=261.70, Epsilon=0.010
# Episode 418: Reward=280.08, Epsilon=0.010
# Episode 419: Reward=253.74, Epsilon=0.010
# Episode 420: Reward=274.39, Epsilon=0.010
# Episode 421: Reward=249.14, Epsilon=0.010
# Episode 422: Reward=258.05, Epsilon=0.010
# Episode 423: Reward=-15.80, Epsilon=0.010
# Episode 424: Reward=258.41, Epsilon=0.010
# Episode 425: Reward=224.46, Epsilon=0.010
# Episode 426: Reward=286.94, Epsilon=0.010
# Episode 427: Reward=257.86, Epsilon=0.010
# Episode 428: Reward=239.58, Epsilon=0.010
# Episode 429: Reward=266.66, Epsilon=0.010
# Episode 430: Reward=262.79, Epsilon=0.010
# Episode 431: Reward=245.88, Epsilon=0.010
# Episode 432: Reward=281.76, Epsilon=0.010
# Episode 433: Reward=286.05, Epsilon=0.010
# Episode 434: Reward=279.42, Epsilon=0.010
# Episode 435: Reward=254.61, Epsilon=0.010
# Episode 436: Reward=246.87, Epsilon=0.010
# Episode 437: Reward=269.25, Epsilon=0.010
# Episode 438: Reward=243.95, Epsilon=0.010
# Episode 439: Reward=307.62, Epsilon=0.010
# Episode 440: Reward=287.74, Epsilon=0.010
# Episode 441: Reward=286.79, Epsilon=0.010
# Episode 442: Reward=237.35, Epsilon=0.010
# Episode 443: Reward=273.45, Epsilon=0.010
# Episode 444: Reward=299.90, Epsilon=0.010
# Episode 445: Reward=252.29, Epsilon=0.010
# Episode 446: Reward=-628.47, Epsilon=0.010
# Episode 447: Reward=180.72, Epsilon=0.010
# Episode 448: Reward=252.87, Epsilon=0.010
# Episode 449: Reward=253.77, Epsilon=0.010
# Episode 450: Reward=256.26, Epsilon=0.010
# Episode 451: Reward=263.42, Epsilon=0.010
# Episode 452: Reward=267.27, Epsilon=0.010
# Episode 453: Reward=269.33, Epsilon=0.010
# Episode 454: Reward=267.25, Epsilon=0.010
# Episode 455: Reward=258.57, Epsilon=0.010
# Episode 456: Reward=279.51, Epsilon=0.010
# Episode 457: Reward=238.67, Epsilon=0.010
# Episode 458: Reward=245.52, Epsilon=0.010
# Episode 459: Reward=255.69, Epsilon=0.010
# Episode 460: Reward=261.72, Epsilon=0.010
# Episode 461: Reward=269.26, Epsilon=0.010
# Episode 462: Reward=266.13, Epsilon=0.010
# Episode 463: Reward=236.43, Epsilon=0.010
# Episode 464: Reward=277.44, Epsilon=0.010
# Episode 465: Reward=282.49, Epsilon=0.010
# Episode 466: Reward=269.72, Epsilon=0.010
# Episode 467: Reward=242.48, Epsilon=0.010
# Episode 468: Reward=267.10, Epsilon=0.010
# Episode 469: Reward=256.89, Epsilon=0.010
# Episode 470: Reward=-203.64, Epsilon=0.010
# Episode 471: Reward=255.95, Epsilon=0.010
# Episode 472: Reward=257.13, Epsilon=0.010
# Episode 473: Reward=254.67, Epsilon=0.010
# Episode 474: Reward=-382.16, Epsilon=0.010
# Episode 475: Reward=-340.12, Epsilon=0.010
# Episode 476: Reward=303.24, Epsilon=0.010
# Episode 477: Reward=31.82, Epsilon=0.010
# Episode 478: Reward=269.71, Epsilon=0.010
# Episode 479: Reward=288.36, Epsilon=0.010
# Episode 480: Reward=265.03, Epsilon=0.010
# Episode 481: Reward=265.31, Epsilon=0.010
# Episode 482: Reward=291.10, Epsilon=0.010
# Episode 483: Reward=281.68, Epsilon=0.010
# Episode 484: Reward=283.41, Epsilon=0.010
# Episode 485: Reward=222.19, Epsilon=0.010
# Episode 486: Reward=274.16, Epsilon=0.010
# Episode 487: Reward=300.29, Epsilon=0.010
# Episode 488: Reward=227.27, Epsilon=0.010
# Episode 489: Reward=229.21, Epsilon=0.010
# Episode 490: Reward=257.02, Epsilon=0.010
# Episode 491: Reward=276.97, Epsilon=0.010
# Episode 492: Reward=271.48, Epsilon=0.010
# Episode 493: Reward=269.34, Epsilon=0.010
# Episode 494: Reward=243.68, Epsilon=0.010
# Episode 495: Reward=285.04, Epsilon=0.010
# Episode 496: Reward=261.00, Epsilon=0.010
# Episode 497: Reward=259.11, Epsilon=0.010
# Episode 498: Reward=269.07, Epsilon=0.010
# Episode 499: Reward=281.57, Epsilon=0.010

# %%
# 6. 可视化训练结果
# 结果可视化
plt.plot(episode_rewards)
plt.title("LunarLander-v3 DQN Training")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.grid(True)
plt.savefig('training_curve.png')

# %%
#7. 模型测试（不渲染窗口）
test_env = gym.make("LunarLander-v3", render_mode="rgb_array")
state, _ = test_env.reset()
while True:
    with torch.no_grad():
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = agent.policy_net(state_tensor).argmax().item()
    next_state, _, terminated, truncated, _ = test_env.step(action)
    state = next_state
    if terminated or truncated:
        break
test_env.close()

# %%
import imageio

test_env = gym.make("LunarLander-v3", render_mode="rgb_array")
state, _ = test_env.reset()
frames = []
while True:
    with torch.no_grad():
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = agent.policy_net(state_tensor).argmax().item()
    next_state, _, terminated, truncated, _ = test_env.step(action)
    frame = test_env.render()
    frames.append(frame)
    state = next_state
    if terminated or truncated:
        break
test_env.close()
imageio.mimsave('lunarlander_test.gif', frames, fps=30)
